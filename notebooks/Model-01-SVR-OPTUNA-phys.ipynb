# %%
import pandas as pd
import numpy as np  


import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.metrics import mean_squared_error
from sklearn.svm import SVR
import sklearn

# %%
from sklearn.model_selection import train_test_split
import optuna

# %%
sol_phys_train = pd.read_csv('../data/interim/solar_phys_train.csv')
sol_phys_train = sol_phys_train.drop('Unnamed: 0', axis=1)
sol_phys_train.head()
# Out:
#    Radiation  Temperature  Pressure  Humidity  WindDirection(Degrees)  Speed
# 0     634.99       289.26   4060.99        41                   14.96   3.02
# 1       1.27       275.93   4034.32        70                  207.43   2.51
# 2       1.21       281.48   4064.99        33                  168.20   2.51
# 3       1.67       285.37   4060.99       101                  152.60   1.51
# 4     839.78       289.82   4062.32        36                  291.95   3.52

# %%
sol_phys_test = pd.read_csv('../data/interim/solar_phys_test.csv')
sol_phys_test = sol_phys_test.drop('Unnamed: 0', axis=1)
sol_phys_test.head()
# Out:
#    id  Temperature  Pressure  Humidity  WindDirection(Degrees)  Speed
# 0   0       288.15   4062.32        44                  312.67   1.51
# 1   1       288.15   4063.65        83                   38.01   3.02
# 2   2       281.48   4051.66        78                  213.62   2.51
# 3   3       280.37   4052.99        98                  176.63   2.01
# 4   4       280.37   4052.99        34                  175.89   3.02

# %%
def objective(trial):
# Invoke suggest methods of a Trial object to generate hyperparameters.

    svr_c = trial.suggest_loguniform('svr_c', 1e-10, 1e10)
    epsilon = trial.suggest_loguniform('epsilon', 1e-1, 1e1)
        

    X = sol_phys_train[[c for c in sol_phys_train if c != 'Radiation']]
    y = sol_phys_train[['Radiation']]
    X_train, X_val, y_train, y_val = sklearn.model_selection.train_test_split(X, y,random_state=0)
    
    
    model = SVR(C=svr_c, epsilon=epsilon, gamma='auto')
    model.fit(X_train, y_train)
    
    y_pred = model.predict(X_val)
    error = sklearn.metrics.mean_squared_error(y_val, y_pred)
    
    
    return error # An objective value linked with the Trial object.

# %%
study = optuna.create_study()
study.optimize(objective, n_trials=100)
study.best_params
# Out:
# /home/miguel/anaconda3/lib/python3.7/site-packages/sklearn/utils/validation.py:744: DataConversionWarning:
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#
# [I 2020-05-03 23:53:02,426] Finished trial#0 with value: 60167.30022419548 with parameters: {'svr_c': 216780.11657183303, 'epsilon': 2.0806480359980952}. Best is trial#0 with value: 60167.30022419548.
# /home/miguel/anaconda3/lib/python3.7/site-packages/sklearn/utils/validation.py:744: DataConversionWarning:
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#
# [I 2020-05-03 23:53:21,177] Finished trial#1 with value: 140487.24468951512 with parameters: {'svr_c': 3.1219896441313255e-08, 'epsilon': 5.047092374049707}. Best is trial#0 with value: 60167.30022419548.
# /home/miguel/anaconda3/lib/python3.7/site-packages/sklearn/utils/validation.py:744: DataConversionWarning:
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#
# [I 2020-05-03 23:57:56,481] Finished trial#2 with value: 58142.99139521143 with parameters: {'svr_c': 1362.804899786038, 'epsilon': 2.005242402918289}. Best is trial#2 with value: 58142.99139521143.
# /home/miguel/anaconda3/lib/python3.7/site-packages/sklearn/utils/validation.py:744: DataConversionWarning:
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#
# [I 2020-05-04 00:03:08,748] Finished trial#3 with value: 72090.53939347596 with parameters: {'svr_c': 2931031.693788779, 'epsilon': 0.3368068921460542}. Best is trial#2 with value: 58142.99139521143.
# /home/miguel/anaconda3/lib/python3.7/site-packages/sklearn/utils/validation.py:744: DataConversionWarning:
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#
# [I 2020-05-04 00:08:13,059] Finished trial#4 with value: 60148.42056647112 with parameters: {'svr_c': 196048.5034052305, 'epsilon': 0.12905093987047014}. Best is trial#2 with value: 58142.99139521143.
# /home/miguel/anaconda3/lib/python3.7/site-packages/sklearn/utils/validation.py:744: DataConversionWarning:
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#
# [I 2020-05-04 00:08:32,491] Finished trial#5 with value: 141926.25475291032 with parameters: {'svr_c': 0.0010076443220677828, 'epsilon': 0.840619059517175}. Best is trial#2 with value: 58142.99139521143.
# /home/miguel/anaconda3/lib/python3.7/site-packages/sklearn/utils/validation.py:744: DataConversionWarning:
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#
# [I 2020-05-04 00:13:07,670] Finished trial#6 with value: 59461.310976296554 with parameters: {'svr_c': 10891.168629211837, 'epsilon': 0.19462294391526683}. Best is trial#2 with value: 58142.99139521143.
# /home/miguel/anaconda3/lib/python3.7/site-packages/sklearn/utils/validation.py:744: DataConversionWarning:
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#
# [I 2020-05-04 00:20:38,137] Finished trial#7 with value: 116940.55343824126 with parameters: {'svr_c': 5217572991.614667, 'epsilon': 1.3764210961892847}. Best is trial#2 with value: 58142.99139521143.
# /home/miguel/anaconda3/lib/python3.7/site-packages/sklearn/utils/validation.py:744: DataConversionWarning:
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#
# [I 2020-05-04 00:21:29,439] Finished trial#8 with value: 130909.19316064761 with parameters: {'svr_c': 8.497225055300936, 'epsilon': 8.659067524316988}. Best is trial#2 with value: 58142.99139521143.
# /home/miguel/anaconda3/lib/python3.7/site-packages/sklearn/utils/validation.py:744: DataConversionWarning:
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#
# [I 2020-05-04 00:22:02,138] Finished trial#9 with value: 135690.1481890632 with parameters: {'svr_c': 4.9006135014139325, 'epsilon': 2.871282742750636}. Best is trial#2 with value: 58142.99139521143.
# /home/miguel/anaconda3/lib/python3.7/site-packages/sklearn/utils/validation.py:744: DataConversionWarning:
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#
# [I 2020-05-04 00:22:28,359] Finished trial#10 with value: 142002.98124721198 with parameters: {'svr_c': 0.0008288192211513484, 'epsilon': 0.5638857326914601}. Best is trial#2 with value: 58142.99139521143.
# /home/miguel/anaconda3/lib/python3.7/site-packages/sklearn/utils/validation.py:744: DataConversionWarning:
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#
# [I 2020-05-04 00:26:17,169] Finished trial#11 with value: 57560.1176283347 with parameters: {'svr_c': 758.0966920806774, 'epsilon': 0.10542386424590683}. Best is trial#11 with value: 57560.1176283347.
# /home/miguel/anaconda3/lib/python3.7/site-packages/sklearn/utils/validation.py:744: DataConversionWarning:
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#
# [I 2020-05-04 00:32:27,820] Finished trial#12 with value: 113921.6389774661 with parameters: {'svr_c': 4264103704.4995604, 'epsilon': 3.622330669795468}. Best is trial#11 with value: 57560.1176283347.
# /home/miguel/anaconda3/lib/python3.7/site-packages/sklearn/utils/validation.py:744: DataConversionWarning:
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#
# [I 2020-05-04 00:35:10,004] Finished trial#13 with value: 77587.73068135911 with parameters: {'svr_c': 173.93415211804262, 'epsilon': 1.193526102659739}. Best is trial#11 with value: 57560.1176283347.
# /home/miguel/anaconda3/lib/python3.7/site-packages/sklearn/utils/validation.py:744: DataConversionWarning:
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-2b0cac246031> in <module>
#       1 study = optuna.create_study()
# ----> 2 study.optimize(objective, n_trials=100)
#       3 study.best_params
#
# ~/anaconda3/lib/python3.7/site-packages/optuna/study.py in optimize(self, func, n_trials, timeout, n_jobs, catch, callbacks, gc_after_trial, show_progress_bar)
#     329             if n_jobs == 1:
#     330                 self._optimize_sequential(
# --> 331                     func, n_trials, timeout, catch, callbacks, gc_after_trial, None
#     332                 )
#     333             else:
#
# ~/anaconda3/lib/python3.7/site-packages/optuna/study.py in _optimize_sequential(self, func, n_trials, timeout, catch, callbacks, gc_after_trial, time_start)
#     624                     break
#     625
# --> 626             self._run_trial_and_callbacks(func, catch, callbacks, gc_after_trial)
#     627
#     628             self._progress_bar.update((datetime.datetime.now() - time_start).total_seconds())
#
# ~/anaconda3/lib/python3.7/site-packages/optuna/study.py in _run_trial_and_callbacks(self, func, catch, callbacks, gc_after_trial)
#     654         # type: (...) -> None
#     655
# --> 656         trial = self._run_trial(func, catch, gc_after_trial)
#     657         if callbacks is not None:
#     658             frozen_trial = self._storage.get_trial(trial._trial_id)
#
# ~/anaconda3/lib/python3.7/site-packages/optuna/study.py in _run_trial(self, func, catch, gc_after_trial)
#     675
#     676         try:
# --> 677             result = func(trial)
#     678         except exceptions.TrialPruned as e:
#     679             message = "Setting status of trial#{} as {}. {}".format(
#
# <ipython-input-5-5ba56ebc5ee4> in objective(trial)
#      12
#      13     model = SVR(C=svr_c, epsilon=epsilon, gamma='auto')
# ---> 14     model.fit(X_train, y_train)
#      15
#      16     y_pred = model.predict(X_val)
#
# ~/anaconda3/lib/python3.7/site-packages/sklearn/svm/_base.py in fit(self, X, y, sample_weight)
#     197
#     198         seed = rnd.randint(np.iinfo('i').max)
# --> 199         fit(X, y, sample_weight, solver_type, kernel, random_seed=seed)
#     200         # see comment on the other call to np.iinfo in this file
#     201
#
# ~/anaconda3/lib/python3.7/site-packages/sklearn/svm/_base.py in _dense_fit(self, X, y, sample_weight, solver_type, kernel, random_seed)
#     256                 cache_size=self.cache_size, coef0=self.coef0,
#     257                 gamma=self._gamma, epsilon=self.epsilon,
# --> 258                 max_iter=self.max_iter, random_seed=random_seed)
#     259
#     260         self._warn_from_fit_status()
#
# KeyboardInterrupt:

# %%
'svr_c': 699.4904770372533, 'epsilon': 1.5723760456136062

# %%
X = sol_phys_train[[c for c in sol_phys_train if c != 'Radiation']]
y = sol_phys_train[['Radiation']]
X_train, X_val, y_train, y_val = sklearn.model_selection.train_test_split(X, y,random_state=0)

# %%
svr_c = 699.4904770372533
epsilon = 1.5723760456136062

model = SVR(kernel='rbf', C=svr_c, epsilon=epsilon, gamma='auto')
model.fit(X_train, y_train)
# Out:
# /home/miguel/anaconda3/lib/python3.7/site-packages/sklearn/utils/validation.py:744: DataConversionWarning:
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-5de581f396f8> in <module>
#       6
#       7
# ----> 8 predict = model.predict(X_valid)
#       9 np.sqrt(mean_squared_error(predict, y_valid))
#
# NameError: name 'X_valid' is not defined

# %%
predict = model.predict(X_val)
np.sqrt(mean_squared_error(predict, y_val))
# Out:
# 239.87818239194658

# %%
predic_testf = model.predict(sol_phys_test.drop('id',axis=1))

# %%
submission1 = pd.DataFrame()

# %%
submission1['id'] = sol_phys_test['id']

# %%
submission1['Radiation'] = predic_testf

# %%
#submission1.set_index('id', inplace=True)
submission1.to_csv('../data/processed/submission1.csv')

# %%
submission1.describe()
# Out:
#                 id    Radiation
# count  8172.000000  8172.000000
# mean   4085.500000   193.237404
# std    2359.197533   160.349376
# min       0.000000  -119.238560
# 25%    2042.750000    61.507192
# 50%    4085.500000   176.080493
# 75%    6128.250000   278.912315
# max    8171.000000  1040.773669

# %%
sol_phys_train.describe()
# Out:
#           Radiation   Temperature      Pressure      Humidity  \
# count  24514.000000  24514.000000  24514.000000  24514.000000
# mean     208.062687    283.763923   4056.016801     75.002284
# std      316.133238      3.452542      7.299362     25.999994
# min        1.130000    274.260000   4024.990000     11.000000
# 25%        1.230000    280.930000   4052.990000     55.000000
# 50%        2.720000    283.150000   4056.990000     85.000000
# 75%      359.927500    285.930000   4060.990000     97.000000
# max     1601.260000    294.820000   4074.320000    103.000000
#
#        WindDirection(Degrees)         Speed
# count            24514.000000  24514.000000
# mean               143.129305      2.793646
# std                 82.939584      1.556280
# min                  0.090000      0.000000
# 25%                 81.872500      1.510000
# 50%                147.585000      2.510000
# 75%                179.217500      3.520000
# max                359.950000     17.600000
