# %%
import pandas as pd
import numpy as np  


import seaborn as sns
import matplotlib.pyplot as plt


from sklearn.metrics import mean_squared_error
from sklearn.svm import SVR
import sklearn


from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
import optuna

import xgboost as xgb

# %%
solar_train = pd.read_csv('../data/external/solar_train.csv')
solar_train.head()
# Out:
#      UNIXTime                    Data      Time  Radiation  Temperature  \
# 0  1475175023   9/29/2016 12:00:00 AM  08:50:23     634.99           61
# 1  1481799902  12/15/2016 12:00:00 AM  01:05:02       1.27           37
# 2  1478339417   11/4/2016 12:00:00 AM  23:50:17       1.21           47
# 3  1472887208    9/2/2016 12:00:00 AM  21:20:08       1.67           54
# 4  1478724901   11/9/2016 12:00:00 AM  10:55:01     839.78           62
#
#    Pressure  Humidity  WindDirection(Degrees)  Speed TimeSunRise TimeSunSet
# 0     30.46        41                   14.96   6.75    06:13:00   18:13:00
# 1     30.26        70                  207.43   5.62    06:50:00   17:46:00
# 2     30.49        33                  168.20   5.62    06:25:00   17:47:00
# 3     30.46       101                  152.60   3.37    06:07:00   18:37:00
# 4     30.47        36                  291.95   7.87    06:28:00   17:45:00

# %%
sol_phys_train = pd.read_csv('../data/interim/solar_phys_time_train.csv')
sol_phys_train = sol_phys_train.drop('Unnamed: 0', axis=1)
sol_phys_train.head()
# Out:
#    Radiation  Temperature  Pressure  Humidity  WindDirection(Degrees)  Speed  \
# 0     634.99       289.26   4060.99        41                  0.0416   3.02
# 1       1.27       275.93   4034.32        70                  0.5762   2.51
# 2       1.21       281.48   4064.99        33                  0.4672   2.51
# 3       1.67       285.37   4060.99       101                  0.4239   1.51
# 4     839.78       289.82   4062.32        36                  0.8110   3.52
#
#        Time   SunTime  DayOfYear  DayOfWeek
# 0  0.368322  0.500000        273          3
# 1  0.045162  0.455556        350          3
# 2  0.993252  0.473611        309          4
# 3  0.888981  0.520833        246          4
# 4  0.454873  0.470139        314          2

# %%
#Pressure is irrelevant

sol_phys_train.drop('Pressure', axis=1, inplace=True)

# %%
sol_phys_train.head()
# Out:
#    Radiation  Temperature  Humidity  WindDirection(Degrees)  Speed      Time  \
# 0     634.99       289.26        41                  0.0416   3.02  0.368322
# 1       1.27       275.93        70                  0.5762   2.51  0.045162
# 2       1.21       281.48        33                  0.4672   2.51  0.993252
# 3       1.67       285.37       101                  0.4239   1.51  0.888981
# 4     839.78       289.82        36                  0.8110   3.52  0.454873
#
#     SunTime  DayOfYear  DayOfWeek
# 0  0.500000        273          3
# 1  0.455556        350          3
# 2  0.473611        309          4
# 3  0.520833        246          4
# 4  0.470139        314          2

# %%
sol_phys_train['WeekOfYear'] = solar_train['Data'].apply(lambda x:  pd.Period(x.split(" ")[0], freq='W').weekofyear)

# %%
sol_phys_train['Month'] = solar_train['Data'].apply(lambda x:  pd.Period(x.split(" ")[0], freq='M').month)

# %%
sol_phys_train['TimeSunRise'] = pd.to_timedelta(solar_train['TimeSunRise'])/pd.to_timedelta(1, unit='D')
sol_phys_train['TimeSunSet'] = pd.to_timedelta(solar_train['TimeSunSet'])/pd.to_timedelta(1, unit='D')

# %%
sol_phys_train.head()
# Out:
#    Radiation  Temperature  Humidity  WindDirection(Degrees)  Speed      Time  \
# 0     634.99       289.26        41                  0.0416   3.02  0.368322
# 1       1.27       275.93        70                  0.5762   2.51  0.045162
# 2       1.21       281.48        33                  0.4672   2.51  0.993252
# 3       1.67       285.37       101                  0.4239   1.51  0.888981
# 4     839.78       289.82        36                  0.8110   3.52  0.454873
#
#     SunTime  DayOfYear  DayOfWeek  WeekOfYear  Month  TimeSunRise  TimeSunSet
# 0  0.500000        273          3          39      9     0.259028    0.759028
# 1  0.455556        350          3          50     12     0.284722    0.740278
# 2  0.473611        309          4          44     11     0.267361    0.740972
# 3  0.520833        246          4          35      9     0.254861    0.775694
# 4  0.470139        314          2          45     11     0.269444    0.739583

# %%
sol_phys_train.to_csv('../data/interim/solar_pro1_train.csv')

# %%
sol_phys_test = pd.read_csv('../data/interim/solar_phys_time_test.csv')
sol_phys_test = sol_phys_test.drop('Unnamed: 0', axis=1)
sol_phys_test.head()
# Out:
#    Temperature  Pressure  Humidity  WindDirection(Degrees)  Speed      Time  \
# 0       288.15   4062.32        44                  0.8685   1.51  0.399387
# 1       288.15   4063.65        83                  0.1056   3.02  0.503507
# 2       281.48   4051.66        78                  0.5934   2.51  0.180799
# 3       280.37   4052.99        98                  0.4906   2.01  0.285370
# 4       280.37   4052.99        34                  0.4886   3.02  0.198113
#
#     SunTime  DayOfYear  DayOfWeek
# 0  0.470139        314          2
# 1  0.510417        260          4
# 2  0.490972        284          0
# 3  0.456250        346          6
# 4  0.479861        300          2

# %%
#Pressure is irrelevant

sol_phys_test.drop('Pressure', axis=1, inplace=True)

# %%
solar_original_test = pd.read_csv('../data/external/solar_test.csv')
solar_original_test.head()
# Out:
#    id    UNIXTime                    Data      Time  Temperature  Pressure  \
# 0   0  1478720107   11/9/2016 12:00:00 AM  09:35:07           59     30.47
# 1   1  1474063503   9/16/2016 12:00:00 AM  12:05:03           59     30.48
# 2   2  1476109221  10/10/2016 12:00:00 AM  04:20:21           47     30.39
# 3   3  1481475056  12/11/2016 12:00:00 AM  06:50:56           45     30.40
# 4   4  1477493117  10/26/2016 12:00:00 AM  04:45:17           45     30.40
#
#    Humidity  WindDirection(Degrees)  Speed TimeSunRise TimeSunSet
# 0        44                  312.67   3.37    06:28:00   17:45:00
# 1        83                   38.01   6.75    06:10:00   18:25:00
# 2        78                  213.62   5.62    06:16:00   18:03:00
# 3        98                  176.63   4.50    06:47:00   17:44:00
# 4        34                  175.89   6.75    06:21:00   17:52:00

# %%
sol_phys_test['WeekOfYear'] = solar_original_test['Data'].apply(lambda x:  pd.Period(x.split(" ")[0], freq='W').weekofyear)
sol_phys_test['Month'] = solar_original_test['Data'].apply(lambda x:  pd.Period(x.split(" ")[0], freq='M').month)
sol_phys_test['TimeSunRise'] = pd.to_timedelta(solar_original_test['TimeSunRise'])/pd.to_timedelta(1, unit='D')
sol_phys_test['TimeSunSet'] = pd.to_timedelta(solar_original_test['TimeSunSet'])/pd.to_timedelta(1, unit='D')

# %%
sol_phys_test.head()
# Out:
#    Temperature  Humidity  WindDirection(Degrees)  Speed      Time   SunTime  \
# 0       288.15        44                  0.8685   1.51  0.399387  0.470139
# 1       288.15        83                  0.1056   3.02  0.503507  0.510417
# 2       281.48        78                  0.5934   2.51  0.180799  0.490972
# 3       280.37        98                  0.4906   2.01  0.285370  0.456250
# 4       280.37        34                  0.4886   3.02  0.198113  0.479861
#
#    DayOfYear  DayOfWeek  WeekOfYear  Month  TimeSunRise  TimeSunSet
# 0        314          2          45     11     0.269444    0.739583
# 1        260          4          37      9     0.256944    0.767361
# 2        284          0          41     10     0.261111    0.752083
# 3        346          6          49     12     0.282639    0.738889
# 4        300          2          43     10     0.264583    0.744444

# %%
sol_phys_test.to_csv('../data/interim/solar_pro1_tes.csv')

# %%
X = sol_phys_train[[c for c in sol_phys_train if c != 'Radiation']].values
y = sol_phys_train[['Radiation']].values

# %%
X_train, X_val, y_train, y_val = sklearn.model_selection.train_test_split(X, y,random_state=0, test_size=0.30)

# %%
def objective_rm(trial):
# Invoke suggest methods of a Trial object to generate hyperparameters.

    rf_max_depth = trial.suggest_int('rf_max_depth', 2, 64)
    rf_max_estimators = trial.suggest_int('n_estimators', 1, 3000)
        
    
    model = RandomForestRegressor(max_depth=rf_max_depth, criterion='mse', n_estimators = rf_max_estimators)
    model.fit(X_train, y_train)
    
    y_pred = model.predict(X_val)
    error = sklearn.metrics.mean_squared_error(y_val, y_pred)
    
    
    return error # An objective value linked with the Trial object.

# %%
study_rm = optuna.create_study()
study_rm.optimize(objective_rm, n_trials=100)
study_rm.best_params
# Out:
# /home/miguel/.local/lib/python3.7/site-packages/ipykernel_launcher.py:9: DataConversionWarning:
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#
# [I 2020-05-05 22:22:27,923] Finished trial#0 with value: 6971.250833098634 with parameters: {'rf_max_depth': 16, 'n_estimators': 2502}. Best is trial#0 with value: 6971.250833098634.
# /home/miguel/.local/lib/python3.7/site-packages/ipykernel_launcher.py:9: DataConversionWarning:
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#
# [I 2020-05-05 22:26:02,310] Finished trial#1 with value: 6946.910960739936 with parameters: {'rf_max_depth': 36, 'n_estimators': 2045}. Best is trial#1 with value: 6946.910960739936.
# /home/miguel/.local/lib/python3.7/site-packages/ipykernel_launcher.py:9: DataConversionWarning:
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#
# [I 2020-05-05 22:28:55,774] Finished trial#2 with value: 10885.166879204642 with parameters: {'rf_max_depth': 8, 'n_estimators': 2773}. Best is trial#1 with value: 6946.910960739936.
# /home/miguel/.local/lib/python3.7/site-packages/ipykernel_launcher.py:9: DataConversionWarning:
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#
# [I 2020-05-05 22:29:14,189] Finished trial#3 with value: 37383.81722885031 with parameters: {'rf_max_depth': 2, 'n_estimators': 1208}. Best is trial#1 with value: 6946.910960739936.
# /home/miguel/.local/lib/python3.7/site-packages/ipykernel_launcher.py:9: DataConversionWarning:
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#
# [I 2020-05-05 22:34:52,272] Finished trial#4 with value: 6936.365922002296 with parameters: {'rf_max_depth': 46, 'n_estimators': 2618}. Best is trial#4 with value: 6936.365922002296.
# /home/miguel/.local/lib/python3.7/site-packages/ipykernel_launcher.py:9: DataConversionWarning:
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#
# [I 2020-05-05 22:36:55,168] Finished trial#5 with value: 10876.587972583813 with parameters: {'rf_max_depth': 8, 'n_estimators': 1603}. Best is trial#4 with value: 6936.365922002296.
# /home/miguel/.local/lib/python3.7/site-packages/ipykernel_launcher.py:9: DataConversionWarning:
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#
# [I 2020-05-05 22:37:09,961] Finished trial#6 with value: 27954.758768971067 with parameters: {'rf_max_depth': 3, 'n_estimators': 442}. Best is trial#4 with value: 6936.365922002296.
# /home/miguel/.local/lib/python3.7/site-packages/ipykernel_launcher.py:9: DataConversionWarning:
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#
# [I 2020-05-05 22:38:46,287] Finished trial#7 with value: 7306.7362951185005 with parameters: {'rf_max_depth': 13, 'n_estimators': 862}. Best is trial#4 with value: 6936.365922002296.
# /home/miguel/.local/lib/python3.7/site-packages/ipykernel_launcher.py:9: DataConversionWarning:
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#
# [I 2020-05-05 22:38:51,345] Finished trial#8 with value: 7125.057586662393 with parameters: {'rf_max_depth': 37, 'n_estimators': 26}. Best is trial#4 with value: 6936.365922002296.
# /home/miguel/.local/lib/python3.7/site-packages/ipykernel_launcher.py:9: DataConversionWarning:
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#
# [I 2020-05-05 22:39:33,560] Finished trial#9 with value: 6983.127281696629 with parameters: {'rf_max_depth': 54, 'n_estimators': 267}. Best is trial#4 with value: 6936.365922002296.
# /home/miguel/.local/lib/python3.7/site-packages/ipykernel_launcher.py:9: DataConversionWarning:
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#
# [I 2020-05-05 22:46:03,027] Finished trial#10 with value: 6937.218784255316 with parameters: {'rf_max_depth': 56, 'n_estimators': 2904}. Best is trial#4 with value: 6936.365922002296.
# /home/miguel/.local/lib/python3.7/site-packages/ipykernel_launcher.py:9: DataConversionWarning:
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#
# [I 2020-05-05 22:53:56,473] Finished trial#11 with value: 6926.89319302883 with parameters: {'rf_max_depth': 62, 'n_estimators': 2900}. Best is trial#11 with value: 6926.89319302883.
# /home/miguel/.local/lib/python3.7/site-packages/ipykernel_launcher.py:9: DataConversionWarning:
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#
# [I 2020-05-05 22:58:12,504] Finished trial#12 with value: 6919.3514992880955 with parameters: {'rf_max_depth': 64, 'n_estimators': 2263}. Best is trial#12 with value: 6919.3514992880955.
# /home/miguel/.local/lib/python3.7/site-packages/ipykernel_launcher.py:9: DataConversionWarning:
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#
# [I 2020-05-05 23:04:19,532] Finished trial#13 with value: 6967.253624701903 with parameters: {'rf_max_depth': 64, 'n_estimators': 2232}. Best is trial#12 with value: 6919.3514992880955.
# /home/miguel/.local/lib/python3.7/site-packages/ipykernel_launcher.py:9: DataConversionWarning:
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#
# [I 2020-05-05 23:08:02,435] Finished trial#14 with value: 6937.515026257973 with parameters: {'rf_max_depth': 64, 'n_estimators': 1897}. Best is trial#12 with value: 6919.3514992880955.
# /home/miguel/.local/lib/python3.7/site-packages/ipykernel_launcher.py:9: DataConversionWarning:
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#
# [I 2020-05-05 23:13:58,141] Finished trial#15 with value: 6919.11323641113 with parameters: {'rf_max_depth': 55, 'n_estimators': 2987}. Best is trial#15 with value: 6919.11323641113.
# /home/miguel/.local/lib/python3.7/site-packages/ipykernel_launcher.py:9: DataConversionWarning:
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#
# [I 2020-05-05 23:20:52,184] Finished trial#16 with value: 6922.304678150577 with parameters: {'rf_max_depth': 48, 'n_estimators': 2341}. Best is trial#15 with value: 6919.11323641113.
# /home/miguel/.local/lib/python3.7/site-packages/ipykernel_launcher.py:9: DataConversionWarning:
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#
# [I 2020-05-05 23:25:19,722] Finished trial#17 with value: 6934.618529476429 with parameters: {'rf_max_depth': 26, 'n_estimators': 1669}. Best is trial#15 with value: 6919.11323641113.
# /home/miguel/.local/lib/python3.7/site-packages/ipykernel_launcher.py:9: DataConversionWarning:
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#
# [I 2020-05-05 23:28:08,914] Finished trial#18 with value: 6953.140358571856 with parameters: {'rf_max_depth': 44, 'n_estimators': 1203}. Best is trial#15 with value: 6919.11323641113.
# /home/miguel/.local/lib/python3.7/site-packages/ipykernel_launcher.py:9: DataConversionWarning:
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#
# [I 2020-05-05 23:32:13,238] Finished trial#19 with value: 6943.070371724786 with parameters: {'rf_max_depth': 57, 'n_estimators': 2052}. Best is trial#15 with value: 6919.11323641113.
# /home/miguel/.local/lib/python3.7/site-packages/ipykernel_launcher.py:9: DataConversionWarning:
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#
# [I 2020-05-05 23:40:12,928] Finished trial#20 with value: 6935.256829635984 with parameters: {'rf_max_depth': 51, 'n_estimators': 2987}. Best is trial#15 with value: 6919.11323641113.
# /home/miguel/.local/lib/python3.7/site-packages/ipykernel_launcher.py:9: DataConversionWarning:
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#
# [I 2020-05-05 23:46:38,251] Finished trial#21 with value: 6941.85137446626 with parameters: {'rf_max_depth': 47, 'n_estimators': 2363}. Best is trial#15 with value: 6919.11323641113.
# /home/miguel/.local/lib/python3.7/site-packages/ipykernel_launcher.py:9: DataConversionWarning:
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#
# [I 2020-05-05 23:54:46,045] Finished trial#22 with value: 6940.1819990488175 with parameters: {'rf_max_depth': 59, 'n_estimators': 2633}. Best is trial#15 with value: 6919.11323641113.
# /home/miguel/.local/lib/python3.7/site-packages/ipykernel_launcher.py:9: DataConversionWarning:
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#
# [I 2020-05-06 00:01:15,054] Finished trial#23 with value: 6910.148171227751 with parameters: {'rf_max_depth': 41, 'n_estimators': 2298}. Best is trial#23 with value: 6910.148171227751.
# /home/miguel/.local/lib/python3.7/site-packages/ipykernel_launcher.py:9: DataConversionWarning:
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#
# [I 2020-05-06 00:05:23,981] Finished trial#24 with value: 6935.562425708466 with parameters: {'rf_max_depth': 41, 'n_estimators': 1871}. Best is trial#23 with value: 6910.148171227751.
# /home/miguel/.local/lib/python3.7/site-packages/ipykernel_launcher.py:9: DataConversionWarning:
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#
# [I 2020-05-06 00:09:18,724] Finished trial#25 with value: 6941.755117915177 with parameters: {'rf_max_depth': 27, 'n_estimators': 2128}. Best is trial#23 with value: 6910.148171227751.
# /home/miguel/.local/lib/python3.7/site-packages/ipykernel_launcher.py:9: DataConversionWarning:
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#
# [I 2020-05-06 00:12:38,787] Finished trial#26 with value: 6935.762388715812 with parameters: {'rf_max_depth': 28, 'n_estimators': 1324}. Best is trial#23 with value: 6910.148171227751.
# /home/miguel/.local/lib/python3.7/site-packages/ipykernel_launcher.py:9: DataConversionWarning:
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#
# [I 2020-05-06 00:21:09,094] Finished trial#27 with value: 6928.538287257275 with parameters: {'rf_max_depth': 50, 'n_estimators': 2578}. Best is trial#23 with value: 6910.148171227751.
# /home/miguel/.local/lib/python3.7/site-packages/ipykernel_launcher.py:9: DataConversionWarning:
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#
# [I 2020-05-06 00:25:24,221] Finished trial#28 with value: 6929.304262505602 with parameters: {'rf_max_depth': 40, 'n_estimators': 1812}. Best is trial#23 with value: 6910.148171227751.
# /home/miguel/.local/lib/python3.7/site-packages/ipykernel_launcher.py:9: DataConversionWarning:
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#
# [I 2020-05-06 00:31:23,841] Finished trial#29 with value: 6936.682479517761 with parameters: {'rf_max_depth': 60, 'n_estimators': 2404}. Best is trial#23 with value: 6910.148171227751.
# /home/miguel/.local/lib/python3.7/site-packages/ipykernel_launcher.py:9: DataConversionWarning:
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-31-98ddbd10b212> in <module>
#       1 study_rm = optuna.create_study()
# ----> 2 study_rm.optimize(objective_rm, n_trials=100)
#       3 study_rm.best_params
#
# ~/anaconda3/lib/python3.7/site-packages/optuna/study.py in optimize(self, func, n_trials, timeout, n_jobs, catch, callbacks, gc_after_trial, show_progress_bar)
#     329             if n_jobs == 1:
#     330                 self._optimize_sequential(
# --> 331                     func, n_trials, timeout, catch, callbacks, gc_after_trial, None
#     332                 )
#     333             else:
#
# ~/anaconda3/lib/python3.7/site-packages/optuna/study.py in _optimize_sequential(self, func, n_trials, timeout, catch, callbacks, gc_after_trial, time_start)
#     624                     break
#     625
# --> 626             self._run_trial_and_callbacks(func, catch, callbacks, gc_after_trial)
#     627
#     628             self._progress_bar.update((datetime.datetime.now() - time_start).total_seconds())
#
# ~/anaconda3/lib/python3.7/site-packages/optuna/study.py in _run_trial_and_callbacks(self, func, catch, callbacks, gc_after_trial)
#     654         # type: (...) -> None
#     655
# --> 656         trial = self._run_trial(func, catch, gc_after_trial)
#     657         if callbacks is not None:
#     658             frozen_trial = self._storage.get_trial(trial._trial_id)
#
# ~/anaconda3/lib/python3.7/site-packages/optuna/study.py in _run_trial(self, func, catch, gc_after_trial)
#     675
#     676         try:
# --> 677             result = func(trial)
#     678         except exceptions.TrialPruned as e:
#     679             message = "Setting status of trial#{} as {}. {}".format(
#
# <ipython-input-30-dad8d7c06dde> in objective_rm(trial)
#       7
#       8     model = RandomForestRegressor(max_depth=rf_max_depth, criterion='mse', n_estimators = rf_max_estimators)
# ----> 9     model.fit(X_train, y_train)
#      10
#      11     y_pred = model.predict(X_val)
#
# ~/anaconda3/lib/python3.7/site-packages/sklearn/ensemble/_forest.py in fit(self, X, y, sample_weight)
#     381                     verbose=self.verbose, class_weight=self.class_weight,
#     382                     n_samples_bootstrap=n_samples_bootstrap)
# --> 383                 for i, t in enumerate(trees))
#     384
#     385             # Collect newly grown trees
#
# ~/anaconda3/lib/python3.7/site-packages/joblib/parallel.py in __call__(self, iterable)
#     922                 self._iterating = self._original_iterator is not None
#     923
# --> 924             while self.dispatch_one_batch(iterator):
#     925                 pass
#     926
#
# ~/anaconda3/lib/python3.7/site-packages/joblib/parallel.py in dispatch_one_batch(self, iterator)
#     757                 return False
#     758             else:
# --> 759                 self._dispatch(tasks)
#     760                 return True
#     761
#
# ~/anaconda3/lib/python3.7/site-packages/joblib/parallel.py in _dispatch(self, batch)
#     714         with self._lock:
#     715             job_idx = len(self._jobs)
# --> 716             job = self._backend.apply_async(batch, callback=cb)
#     717             # A job can complete so quickly than its callback is
#     718             # called before we get here, causing self._jobs to
#
# ~/anaconda3/lib/python3.7/site-packages/joblib/_parallel_backends.py in apply_async(self, func, callback)
#     180     def apply_async(self, func, callback=None):
#     181         """Schedule a func to be run"""
# --> 182         result = ImmediateResult(func)
#     183         if callback:
#     184             callback(result)
#
# ~/anaconda3/lib/python3.7/site-packages/joblib/_parallel_backends.py in __init__(self, batch)
#     547         # Don't delay the application, to avoid keeping the input
#     548         # arguments in memory
# --> 549         self.results = batch()
#     550
#     551     def get(self):
#
# ~/anaconda3/lib/python3.7/site-packages/joblib/parallel.py in __call__(self)
#     223         with parallel_backend(self._backend, n_jobs=self._n_jobs):
#     224             return [func(*args, **kwargs)
# --> 225                     for func, args, kwargs in self.items]
#     226
#     227     def __len__(self):
#
# ~/anaconda3/lib/python3.7/site-packages/joblib/parallel.py in <listcomp>(.0)
#     223         with parallel_backend(self._backend, n_jobs=self._n_jobs):
#     224             return [func(*args, **kwargs)
# --> 225                     for func, args, kwargs in self.items]
#     226
#     227     def __len__(self):
#
# ~/anaconda3/lib/python3.7/site-packages/sklearn/ensemble/_forest.py in _parallel_build_trees(tree, forest, X, y, sample_weight, tree_idx, n_trees, verbose, class_weight, n_samples_bootstrap)
#     163             curr_sample_weight *= compute_sample_weight('balanced', y, indices)
#     164
# --> 165         tree.fit(X, y, sample_weight=curr_sample_weight, check_input=False)
#     166     else:
#     167         tree.fit(X, y, sample_weight=sample_weight, check_input=False)
#
# ~/anaconda3/lib/python3.7/site-packages/sklearn/tree/_classes.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#    1224             sample_weight=sample_weight,
#    1225             check_input=check_input,
# -> 1226             X_idx_sorted=X_idx_sorted)
#    1227         return self
#    1228
#
# ~/anaconda3/lib/python3.7/site-packages/sklearn/tree/_classes.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     365                                            min_impurity_split)
#     366
# --> 367         builder.build(self.tree_, X, y, sample_weight, X_idx_sorted)
#     368
#     369         if self.n_outputs_ == 1 and is_classifier(self):
#
# KeyboardInterrupt:
